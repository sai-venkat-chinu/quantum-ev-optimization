# %%
import numpy as np
import matplotlib.pyplot as plt

from qiskit_aer import Aer
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram

# Simple quantum circuit (represents decision system)
qc = QuantumCircuit(3, 3)

# Create superposition (all EV possibilities)
qc.h([0,1,2])

# Add simple optimization logic (bias)
qc.cx(0,1)
qc.cx(1,2)

# Measure
qc.measure([0,1,2], [0,1,2])

# Run simulation
backend = Aer.get_backend('aer_simulator')
compiled = transpile(qc, backend)
result = backend.run(compiled, shots=1000).result()

counts = result.get_counts()

print("Measurement Results:", counts)

# Plot histogram
plot_histogram(counts)
# Out:
# Measurement Results: {'101': 127, '110': 130, '100': 138, '011': 120, '111': 145, '001': 102, '010': 111, '000': 127}
